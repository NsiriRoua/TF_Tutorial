# %% [markdown]
# <a href="https://colab.research.google.com/github/NsiriRoua/tensor_flow/blob/main/Tensor_flow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !pip install tensorflow==2.0.0-alpha0
# Out:
# ...
#      |████████████████████████████████| 80.3MB 81kB/s
# ...
#      |████████████████████████████████| 51kB 4.7MB/s
# ...
#      |████████████████████████████████| 419kB 37.8MB/s
# ...
#      |████████████████████████████████| 3.0MB 34.0MB/s
# ...
#   Found existing installation: tensorflow 2.4.1
#     Uninstalling tensorflow-2.4.1:
#       Successfully uninstalled tensorflow-2.4.1
# ...

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %% [markdown]
# ![cap1.PNG](data:image/png;base64,...)

# %% [markdown]
# Let's create this graph

# %%
x=tf.Variable(2,name='x')
y=tf.Variable(4,name='y')
f=x*x*y+y*2
print(f)
# Out:
# tf.Tensor(24, shape=(), dtype=int32)

# %% [markdown]
#  A **TensorFlow** session takes care of placing
# the operations onto devices such as CPUs and GPUs and running them, and it holds
# all the variable values.3
#  The following code creates a session, initializes the variables,
# and evaluates, and f then closes the session (which frees up resources)
